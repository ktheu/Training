# %%
def func1(s):
    '''  
    s: String mit großen oder kleinen Buchstaben ohne Umlaute
    returns: s mit erstem großen Buchtaben

    >>> func1('ApPLe')
    'ApPLe'

    >>> func1('konstant')
    'Konstant'

    '''
    # your code


import doctest
doctest.run_docstring_examples(func1,globals(),optionflags=doctest.NORMALIZE_WHITESPACE)

# %%
def func2(s):
    '''  
    s: String bestehend aus den Zeichen 'R', 'G' oder 'B'
    returns: minimale Anzahl von Zeichen, die man aus s entfernen muss, damit keine zwei gleiche Zeichen nebeneinander
    stehen.
    
    >>> func2('RRG')
    1

    >>> func2('RRRRR')
    4

    >>> func2('BRBG')
    0
    '''
    # your code

import doctest
doctest.run_docstring_examples(func2,globals(),optionflags=doctest.NORMALIZE_WHITESPACE)

# %%
def func3(s):
    '''  
    s: String mit zwei positiven ganze Zahlen a und b mit a <= b.
    a wird in jedem Schritt verdreifacht, b wird in jedem Schritt verdoppelt
    returns: Anzahl Schritte, damit a > b
    
    >>> func3('4 7')
    2

    >>> func3('4 9')
    3

    >>> func3('1 1')
    1
    '''
    # your code

import doctest
doctest.run_docstring_examples(func3,globals(),optionflags=doctest.NORMALIZE_WHITESPACE)

# %%
def func4(n):
    '''  
    n: positive ganze Zahl, eine Entfernung
    Wir können Schritte der Länge 1,2,3,4,5 machen. 
    returns: Die minimale Anzahl von Schritten, die wir machen müssen, um genau Entfernung n zurückzulegen.
    
    >>> func4(5)
    1

    >>> func4(12)
    3

    >>> func4(24)
    5
    '''
    # your code

import doctest
doctest.run_docstring_examples(func4,globals(),optionflags=doctest.NORMALIZE_WHITESPACE)

# %%
def func5(s):
    '''  
    s: String aus großen und kleinen Buchstaben ohne Umlaute.
    returns: s nur mit großen Buchstaben, falls in s mehr große als kleine Buchstaben vorkommen
                                          sonst: s nur mit kleinen Buchstaben
    
    >>> func5('HoUse')
    'house'

    >>> func5('ViP')
    'VIP'

    >>> func5('maTRIx')
    'matrix'
    '''
    # your code

import doctest
doctest.run_docstring_examples(func5,globals(),optionflags=doctest.NORMALIZE_WHITESPACE)

# %%
def func6(s):
    '''  
    s: String aus zwei positiven ganzen Zahlen n und k.

    Die Operation op verändert die Zahl n:
        Falls die letzte Ziffer von n keine 0: n wird um 1 erniedrigt
        Falls die letzte Ziffer von n eine 0: die letzte Ziffer von n wird entfernt
        
    returns: Ergebnis, wenn wir k-mal die Operation op auf n anwenden.

   
    
    >>> func6('512 4')
    50

    >>> func6('1000000000 9')
    1
    '''
    # your code


import doctest
doctest.run_docstring_examples(func6,globals(),optionflags=doctest.NORMALIZE_WHITESPACE)

# %%
def func7(n):
    '''  
    n: positive ganze Zahl

    Eine Zahl heißt 'lucky number', wenn sie nur aus den lucky-Ziffern 4 oder 7 besteht.
    Eine Zahl heißt 'nearly lucky number', wenn die Anzahl ihrer lucky-Ziffern eine lucky number ist.

    returns: 'YES', falls n nearly lucky number, sonst 'NO'
  
    
    >>> func7(40047)
    'NO'

    >>> func7(77477714)
    'YES'
    '''
    # your code

import doctest
doctest.run_docstring_examples(func7,globals(),optionflags=doctest.NORMALIZE_WHITESPACE)

# %%
def func8(s1, s2):
    '''  
    s1, s2: strings
    returns: 'YES', wenn s2 das von rechts nach links gelesene s1 ist, sonst 'NO'
    
    >>> func8('code','edoc')
    'YES'

    >>> func8('abb','aba')
    'NO'

    '''
    # your code

import doctest
doctest.run_docstring_examples(func8,globals(),optionflags=doctest.NORMALIZE_WHITESPACE)

# %%
def func9(a, b):
    '''  
    a, b = gleich lange Listen mit nicht negativen ganzen Zahlen

    In eine Straßenbahn an Station i steigen a[i] Personen aus und b[i] Personen ein.
    returns: die maximale Anzahl Personen in der Straßenbahn
    
    
    >>> func9([0,2,4,4],[3,5,2,0])
    6

    >>> func9([0,2,0,5,2],[2,1,6,2,1])
    7
    '''
    # your code
        

import doctest
doctest.run_docstring_examples(func9,globals(),optionflags=doctest.NORMALIZE_WHITESPACE)
